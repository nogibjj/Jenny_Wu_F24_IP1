# %% [markdown]
# # Creating a Descriptive Statistic Summary Report
# The purpose of this notebook is to utilize pandas, matpoltlib.pyplot, and a library of functions as listed in lib.py to analyze and visualize a dataset.

# %%
# First we start by importing the functions in lib
import sys

sys.path.append("python_files/main_files")
import lib

# %%
# Then, we call the functions to read the data in.
csv = "https://raw.githubusercontent.com/fivethirtyeight/data/master/congress-demographics/data_aging_congress.csv"

general_df = lib.load_and_preprocess(csv)

# %%
# Return the descriptive statistics
desc_stats = lib.get_summary_stats(general_df, "age_years")
print(desc_stats)
# Out:
# The average age of a Congress member from during a  53.732
# The median age of a Congress member from during a 53.451
# Standard Deviation between the ages of Congress members is 10.763
# count    29120.000000
# mean        53.732475
# std         10.763105
# min         23.665982
# 25%         45.809719
# 50%         53.451061
# 75%         61.216290
# max         98.080767
# Name: age_years, dtype: float64
# count    29120.000000
# mean        53.732475
# std         10.763105
# min         23.665982
# 25%         45.809719
# 50%         53.451061
# 75%         61.216290
# max         98.080767
# Name: age_years, dtype: float64

# %%
# Run the functions to return the charts
lib.hist_cong_age(general_df, "age_years")
lib.age_dist_50(general_df, desc_stats)
# Out:
# /Users/jw/Desktop/MIDS F24/IDS 706 Data Eng/Jenny_Wu_F24_IP1-1/python_files/main_files/lib.py:59: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   general_df.groupby(["chamber", "age_group"]).size().unstack(fill_value=0)
